# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
import openpyxl

# %%
df = pd.read_csv('data_index.csv')

# %%
df.head(5)
# Out:
#           論文 entry  R1-   R2 organocatalyst  organocatalyst(mol%) under  \
# 0        NaN   NaN  NaN  NaN            NaN                   NaN   NaN
# 1        NaN   NaN  NaN  NaN            NaN                   NaN   NaN
# 2        NaN   NaN  NaN  NaN            NaN                   NaN   NaN
# 3  ol301095j   NaN  NaN  NaN            NaN                   NaN   NaN
# 4        NaN   NaN  NaN  NaN            NaN                   NaN   NaN
#
#   temp(℃)  time(h)  Cu(OAc)2(mol%)  AcOH(mol%)  収率(%)
# 0     NaN      NaN             NaN         NaN    NaN
# 1     NaN      NaN             NaN         NaN    NaN
# 2     NaN      NaN             NaN         NaN    NaN
# 3     NaN      NaN             NaN         NaN    NaN
# 4     NaN      NaN             NaN         NaN    NaN

# %%
df.insert(3, 'R1-img', '')
df.insert(6, 'organocatalyst-img', '')

# %%
df.head()
# Out:
#           論文 entry  R1- R1-img   R2 organocatalyst organocatalyst-img  \
# 0        NaN   NaN  NaN         NaN            NaN
# 1        NaN   NaN  NaN         NaN            NaN
# 2        NaN   NaN  NaN         NaN            NaN
# 3  ol301095j   NaN  NaN         NaN            NaN
# 4        NaN   NaN  NaN         NaN            NaN
#
#    organocatalyst(mol%) under temp(℃)  time(h)  Cu(OAc)2(mol%)  AcOH(mol%)  \
# 0                   NaN   NaN     NaN      NaN             NaN         NaN
# 1                   NaN   NaN     NaN      NaN             NaN         NaN
# 2                   NaN   NaN     NaN      NaN             NaN         NaN
# 3                   NaN   NaN     NaN      NaN             NaN         NaN
# 4                   NaN   NaN     NaN      NaN             NaN         NaN
#
#    収率(%)
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %%
file_name = 'data_index.xlsx'

# %%
df.to_excel(file_name, index=False)

# %%
wb = openpyxl.load_workbook(file_name)

# %%
ws = wb.active # active なsheet

# %%
def toImgFromSmiles(smiles, name):
    mol = Chem.MolFromSmiles(smiles)
    return Draw.MolToFile(mol, f'./imgs/{name}.png', size=(300, 300))
    # return Draw.MolsToGridImage([mol])

# %%
# from PIL import Image
# img = Image.open('./imgs/C10.png')

# %%
from openpyxl.drawing.image import Image as XLImage

def image_column(worksheet, smiles_column, image_column):
    ws = worksheet
    # 行数を取得
    R_NUM = len(list(ws.rows))

    # 画像貼り付け
    # 行番号は1始まり。1行目はヘッダなので飛ばす
    for i in range(1, R_NUM):
        idx = i + 1
        smiles_col_name = smiles_column + str(idx)
        cell_name = image_column + str(idx)
        smiles = ws[smiles_col_name].value
        if smiles in [None, '-']: continue
        print(smiles)

        try:
            # 画像ファイルのロード
            toImgFromSmiles(smiles, smiles_col_name)
            img = XLImage(f'./imgs/{smiles_col_name}.png')
            img.width = 200
            img.height = 200
            # 画像を貼り付ける
            ws.add_image(img, cell_name)
            # セルの高さを調整
            ws.row_dimensions[idx].height = img.height
            ws[cell_name].value = ''
        except FileNotFoundError as e:
            print('error ', e)
            # 画像ファイルが見つからない場合はスキップ
            pass

image_column(ws, 'C', 'D')
image_column(ws, 'F', 'G')

# 保存
wb.save(file_name)
# Out:
# CC1=CC=CC=C1
# CC1=CC=C(N)C=C1
# CC1=CC=C(OC)C=C1
# CC1=CC=C
=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# O=C1C(C=C(OC)C(C(C)(C)C)=C1)=O
# ClC1=CC=C(C(O)=O)C(O)=C1
# ClC1=CC=C(C(O)=O)C(O)=C1
# OC1=CC(C)=CC=C1C(O)=O
# OC1=CC(C)=CC=C1C(O)=O
# OC1=CC(OC)=CC=C1C(O)=O
# OC1=CC(OC)=CC=C1C(O)=O
# OC1=CC(OC)=CC=C1C(O)=O
# COC1=CC(OC)=C(C(O)=O)C(O)=C1
# COC1=CC(OC)=C(C(O)=O)C(O)=C1
# COC1=CC(OC)=C(C(O)=O)C(O)=C1
# CC(/N=N/C(C)(C#N)C)(C#N)C
# O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
# O=C1C(C=C(O)C(C(C)(C)C)=C1)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC(O)=CC(O)=C1C(O)=O
# OC1=CC=CC=C1
# O=C(C1=CC=CC=C1)O
# OC1=C(C(O)=O)C=CC=C1
# O=C(C1=C(OC)C=CC=C1)O
# OC1=C(C(OC)=O)C=CC=C1
# OC1=C(CC(O)=O)C=CC=C1
# CC(O)=O
# CC1=CC=C(S(=O)(O)=O)C=C1
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(OC)=CC(OC)=C1C(O)=O
# OC1=CC(O)=CC=C1C(O)=O
# OC1=CC=CC(O)=C1C(O)=O
# OC1=CC=CC=C1C(O)=O
# OC1=CC=C(C(O)=O)C=C1

# %%
xls_df = pd.read_excel(file_name)

# %%
xls_df
# Out:
#             論文 entry           R1-  R1-img   R2         organocatalyst  \
# 0          NaN   NaN           NaN       0  NaN                    NaN
# 1          NaN   NaN           NaN       0  NaN                    NaN
# 2          NaN   NaN           NaN       0  NaN                    NaN
# 3    ol301095j   NaN           NaN       0  NaN                    NaN
# 4          NaN   NaN           NaN       0  NaN                    NaN
# ..         ...   ...           ...     ...  ...                    ...
# 208        NaN   NaN           NaN       0  NaN                    NaN
# 209         S2     1  CC1=CC=CC=C1       0    H  OC1=CC(O)=CC=C1C(O)=O
# 210        NaN     2  CC1=CC=CC=C1       0    H  OC1=CC=CC(O)=C1C(O)=O
# 211        NaN     3  CC1=CC=CC=C1       0    H     OC1=CC=CC=C1C(O)=O
# 212        NaN     4  CC1=CC=CC=C1       0    H   OC1=CC=C(C(O)=O)C=C1
#
#      organocatalyst-img  organocatalyst(mol%) under temp(℃)  time(h)  \
# 0                     0                   NaN   NaN     NaN      NaN
# 1                     0                   NaN   NaN     NaN      NaN
# 2                     0                   NaN   NaN     NaN      NaN
# 3                     0                   NaN   NaN     NaN      NaN
# 4                     0                   NaN   NaN     NaN      NaN
# ..                  ...                   ...   ...     ...      ...
# 208                   0                   NaN   NaN     NaN      NaN
# 209                   0                   5.0    O2      90      2.0
# 210                   0                   5.0    O2      90      2.0
# 211                   0                   5.0    O2      90      2.0
# 212                   0                   5.0    O2      90      2.0
#
#      Cu(OAc)2(mol%)  AcOH(mol%)  収率(%)
# 0               NaN         NaN    NaN
# 1               NaN         NaN    NaN
# 2               NaN         NaN    NaN
# 3               NaN         NaN    NaN
# 4               NaN         NaN    NaN
# ..              ...         ...    ...
# 208             NaN         NaN    NaN
# 209             0.0         0.0    4.0
# 210             0.0         0.0    6.0
# 211             0.0         0.0    3.0
# 212             0.0         0.0    3.0
#
# [213 rows x 14 columns]

# %%
def toImgFromSmiles(smiles):
    mol = Chem.MolFromSmiles(smiles)
    return Draw.MolsToGridImage([mol])

# %%
Draw.MolsToGridImage([mol])
