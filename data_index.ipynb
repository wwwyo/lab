# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
import openpyxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [15], line 4
#       2 from rdkit import Chem
#       3 from rdkit.Chem import Draw
# ----> 4 import openpyxl
#
# ModuleNotFoundError: No module named 'openpyxl'

# %%
df = pd.read_csv('data_index.csv')
# Out:
#           論文 entry               R1-   R2                 organocatalyst  \
# 0        NaN   NaN               NaN  NaN                            NaN
# 1        NaN   NaN               NaN  NaN                            NaN
# 2        NaN   NaN               NaN  NaN                            NaN
# 3  ol301095j   NaN               NaN  NaN                            NaN
# 4        NaN   NaN               NaN  NaN                            NaN
# 5     Table1     1      CC1=CC=CC=C1    H  O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
# 6        NaN     2   CC1=CC=C(N)C=C1    H  O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
# 7        NaN     3  CC1=CC=C(OC)C=C1    H  O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
# 8        NaN     4  CC1=CC=C(Cl)C=C1    H  O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
# 9        NaN     5   CC1=CC=C(F)C=C1    H  O=C1C(C(C)(C)C)=CC(C(O)=C1)=O
#
#    organocatalyst(mol%) under temp(℃)  time(h)  Cu(OAc)2(mol%)  AcOH(mol%)  \
# 0                   NaN   NaN     NaN      NaN             NaN         NaN
# 1                   NaN   NaN     NaN      NaN             NaN         NaN
# 2                   NaN   NaN     NaN      NaN             NaN         NaN
# 3                   NaN   NaN     NaN      NaN             NaN         NaN
# 4                   NaN   NaN     NaN      NaN             NaN         NaN
# 5                   1.5    O2      rt     20.0             0.0         0.0
# 6                   1.5    O2      rt     20.0             0.0         0.0
# 7                   1.5    O2      rt     20.0             0.0         0.0
# 8                   1.5    O2      rt     20.0             0.0         0.0
# 9                   1.5    O2      rt     20.0             0.0         0.0
#
#    収率(%)
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5   87.0
# 6   76.0
# 7   93.0
# 8   90.0
# 9   91.0

# %%
smile = df.iloc[5,2]
mol = Chem.MolFromSmiles(smile)

# %%
Draw.MolsToGridImage([mol])
